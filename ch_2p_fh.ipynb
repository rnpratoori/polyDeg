# %% [markdown]
# # Cahn-Hilliard Equation using Flory-Huggins
#
# This is the implementation for Cahn-Hilliard Equation for two phase separation in 2D using FEniCSx.
# The boundary-value problem is described by:
# $$\frac{\partial c}{\partial t} - \nabla \cdot M \left( \nabla \left( \frac{\partial f}{\partial c} - \frac{\epsilon^2}{2} \Delta c \right) \right) = 0 \quad \in \Omega$$
#
# We use split formulation to rephrase the fourth-order equation into two coupled second-order equations:
# $$
# \begin{aligned}
# \frac{\partial c}{\partial t} - \nabla \cdot M \nabla \mu &= 0 \quad \in \Omega\\
# \mu - \frac{\partial f}{\partial c} + \frac{\epsilon^2}{2} \Delta c &= 0 \quad \in \Omega
# \end{aligned}
# $$
#
# ## Variational formulation
#
# ### Weak formulation
#
# The variational form of the equations are:
# $$
# \begin{aligned}
# \int_\Omega \frac{\partial c}{\partial t} q dx + \int_\Omega M \nabla \mu \cdot \nabla q dx = 0 \\
# \int_\Omega \mu v dx - \int_\Omega \frac{\partial f}{\partial c} v dx - \int_\Omega \frac{\epsilon^2}{2} \nabla c \cdot \nabla v dx = 0
# \end{aligned}
# $$
#
# ### Crank-Nicholson time stepper
#
# The sampling of the first PDE at time $t_{n+1}$ is given by:
# $$
# \begin{aligned}
# \int_\Omega \frac{c_{n+1} - c_n}{dt} q dx + \frac{1}{2} \int_\Omega M \nabla \left( \mu_{n+1} + \mu_n \right) \cdot \nabla q dx = 0 \\
# \int_\Omega \mu_{n+1} v dx - \int_\Omega \frac{d f_{n+1}}{dc} v dx - \int_\Omega \frac{\epsilon^2}{2} \nabla c_{n+1} \cdot \nabla v dx = 0
# \end{aligned}
# $$
#
# ## Problem definition
#
# - Domain: $\Omega = [0,1] \times [0,1]$
# - Local energy: $f = \frac{R T}{V} \left[ \frac{\phi_1}{N_1} \ln \phi_1 + \frac{\phi_2}{N_2} \ln \phi_2 + \chi_{1,2} \phi_1 \phi_2 \right]$
# - Gradient energy coefficent: $\lambda = 1 \times 10^{-2}$
# - Mobility coefficient: $M = 1$
# - Flory-Huggins parameter: $\chi_{1,2} = 3$
# - Length of polymer chains: $N_1 = N_2 = 1$

# %%
# Import Libraries
from mpi4py import MPI
from dolfinx import mesh, fem, io, log, default_real_type
import numpy as np
import ufl
from basix.ufl import element, mixed_element
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from petsc4py import PETSc
from pathlib import Path

# %%
# Define simulation parameters
J2eV = 1 # convert to eV
R = 1.0
T = 1.0
V = 1.0
epsilon_ = 0.02
lambda_ = epsilon_**2 / 2
M = 1.0
chi = 2.0
N1 = 5.0
N2 = 5.0
dt = 5.0e-05
T = 1.0e-03 # End time
num_steps = T / dt # Number of time steps
# Print properties
print(f"M={M}, V={V}, R={R}, lambda={lambda_}")

# Create mesh
domain = mesh.create_rectangle(MPI.COMM_WORLD, [np.array([0, 0]), np.array([2, 1])], [512, 256])

# Create FunctionSpace
P1 = element("Lagrange", domain.basix_cell(), 1, dtype=default_real_type)
ME = fem.functionspace(domain, mixed_element([P1, P1]))

# Apply Dirichlet BCs
# Identify the facets on the left and right boundaries
facets = mesh.locate_entities_boundary(domain, domain.topology.dim - 1, lambda x: np.full(x.shape[1], True, dtype=bool))

# Define variational problem
# Define trial and test functions
u = fem.Function(ME)
# Previous solution
u0 = fem.Function(ME)
q, v = ufl.TestFunctions(ME)
# Split mixed functions
c, mu = ufl.split(u)
c0, mu0 = ufl.split(u0)

# Initial condition
u.x.array[:] = 0.0
rng = np.random.default_rng(2)
u.sub(0).interpolate(lambda x: 0.45 + 0.02 * (0.5 - rng.random(x.shape[1])))
u.x.scatter_forward()

# Compute df/dc
c = ufl.variable(c)
f = (R * T / V) * (c * ufl.ln(c) / N1 + (1 - c) * ufl.ln(1 - c) / N2 + chi * c * (1 - c))
dfdc = ufl.diff(f, c)

# Define residuals
F0 = ufl.inner(c, q) * ufl.dx - ufl.inner(c0, q) * ufl.dx + (dt/2) * ufl.inner(ufl.grad(mu + mu0), ufl.grad(q)) * ufl.dx
F1 = ufl.inner(mu, v) * ufl.dx - ufl.inner(dfdc, v) * ufl.dx - lambda_ * ufl.inner(ufl.grad(c), ufl.grad(v)) * ufl.dx
F = F0 + F1

# Create NonlinearProblem
problem = NonlinearProblem(F, u)

# Create Newton Solver
log.set_log_level(log.LogLevel.INFO)
solver = NewtonSolver(domain.comm, problem)
solver.convergence_criterion = "incremental"
solver.rtol = np.sqrt(np.finfo(default_real_type).eps) * 1e-2
ksp = solver.krylov_solver
opts = PETSc.Options()  # type: ignore
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "preonly"
opts[f"{option_prefix}pc_type"] = "lu"
sys = PETSc.Sys()  # type: ignore
# For factorisation prefer MUMPS, then superlu_dist, then default
use_superlu = PETSc.IntType == np.int64  # or PETSc.ScalarType == np.complex64
if sys.hasExternalPackage("mumps") and not use_superlu:
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
elif sys.hasExternalPackage("superlu_dist"):
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "superlu_dist"
ksp.setFromOptions()

# Post-process
# Save solution to file
t = 0.0
results_folder = Path("results")
results_folder.mkdir(exist_ok=True, parents=True)
filename = results_folder / "out_ch2p"
with io.XDMFFile(domain.comm, filename.with_suffix(".xdmf"), "w", io.XDMFFile.Encoding.ASCII) as xdmf:
    xdmf.write_mesh(domain)
# Get the sub-space for c
V0, dofs = ME.sub(0).collapse()

# Time-stepping
c = u.sub(0)
u0.x.array[:] = u.x.array
while t < T:
    t += dt
    r = solver.solve(u)
    print(f"Step {int(t / dt)}: num iterations: {r[0]}")
    u0.x.array[:] = u.x.array
    xdmf.write_function(c, t)
xdmf.close()
# Out:
# M=1.0, V=1.0, R=1.0, lambda=0.0002
# [2025-03-12 11:54:39.511] [info] Extract basic topology: 786432->786432
# [2025-03-12 11:54:39.522] [info] Build local dual graph
# [2025-03-12 11:54:39.522] [info] Build local part of mesh dual graph (mixed)
# [2025-03-12 11:54:39.934] [info] GPS pseudo-diameter:(1534) 261121-1022
# [2025-03-12 11:54:39.978] [info] Create topology (single cell type)
# [2025-03-12 11:54:39.978] [info] Create topology (generalised)
# [2025-03-12 11:54:39.996] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 1
# [2025-03-12 11:54:39.996] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 1
# [2025-03-12 11:54:40.063] [info] Compute ghost indices
# [2025-03-12 11:54:40.063] [info] Computing communication graph edges (using PCX algorithm). Number of input edges: 0
# [2025-03-12 11:54:40.063] [info] Finished graph edge discovery using PCX algorithm. Number of discovered edges 0
# [2025-03-12 11:54:40.174] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# [2025-03-12 11:54:40.174] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# [2025-03-12 11:54:40.215] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# [2025-03-12 11:54:40.215] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# [2025-03-12 11:54:40.215] [info] Number of neighbourhood source ranks in distribute_to_postoffice: 0
# [2025-03-12 11:54:40.217] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# [2025-03-12 11:54:40.217] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# [2025-03-12 11:54:40.217] [info] Neighbourhood destination ranks from post office in distribute_data (rank, num dests, num dests/mpi_size): 0, 0, 0
# [2025-03-12 11:54:40.218] [info] Checking required entities per dimension
# [2025-03-12 11:54:40.232] [info] Cell type: 0 dofmap: 262144x3
# [2025-03-12 11:54:40.250] [info] Global index computation
# [2025-03-12 11:54:40.251] [info] Got 1 index_maps
# [2025-03-12 11:54:40.265] [info] Get global indices
# [2025-03-12 11:54:40.330] [info] Checking required entities per dimension
# [2025-03-12 11:54:40.330] [info] Cell type: 0 dofmap: 262144x6
# [2025-03-12 11:54:40.351] [info] Global index computation
# [2025-03-12 11:54:40.352] [info] Got 1 index_maps
# [2025-03-12 11:54:40.355] [info] Get global indices
# [2025-03-12 11:54:40.360] [info] Computing mesh entities of dimension 1
# [2025-03-12 11:54:40.506] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# [2025-03-12 11:54:40.506] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# [2025-03-12 11:54:40.557] [info] Requesting connectivity (1, 0) - (2, 0)
# [2025-03-12 11:54:40.557] [info] Computing mesh connectivity 1-2 from transpose.
# [2025-03-12 11:54:40.569] [info] Requesting connectivity (1, 0) - (0, 0)
# [2025-03-12 11:54:40.569] [info] Requesting connectivity (1, 0) - (1, 0)
# [2025-03-12 11:54:40.569] [info] Requesting connectivity (0, 0) - (2, 0)
# [2025-03-12 11:54:40.569] [info] Computing mesh connectivity 0-2 from transpose.
# [2025-03-12 11:54:40.578] [info] Requesting connectivity (2, 0) - (0, 0)
# [2025-03-12 11:54:41.967] [info] Column ghost size increased from 0 to 0
# [2025-03-12 11:54:42.012] [info] Adding mesh to node "/Xdmf/Domain"
# [2025-03-12 11:54:42.015] [info] Adding topology data to node /Xdmf/Domain/Grid
# [2025-03-12 11:54:42.175] [info] Adding geometry data to node "/Xdmf/Domain/Grid"
# [2025-03-12 11:54:43.073] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:54:47.742] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:54:49.104] [info] Newton iteration 2: r (abs) = 9.284504111523469e-07 (tol = 1e-10), r (rel) = 4.3085220244512255e-07 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:54:49.351] [info] PETSc Krylov solver starting to solve system.
# Step 1: num iterations: 3
# [2025-03-12 11:54:51.021] [info] Newton iteration 3: r (abs) = 6.114312419914391e-15 (tol = 1e-10), r (rel) = 2.837378217419322e-15 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:54:51.021] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:54:51.021] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:54:51.447] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:54:53.595] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:54:55.340] [info] Newton iteration 2: r (abs) = 1.4108224456190778e-08 (tol = 1e-10), r (rel) = 1.4169396887073645e-08 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:54:55.575] [info] PETSc Krylov solver starting to solve system.
# Step 2: num iterations: 3
# [2025-03-12 11:54:57.010] [info] Newton iteration 3: r (abs) = 6.119106661052571e-15 (tol = 1e-10), r (rel) = 6.14563874738636e-15 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:54:57.010] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:54:57.010] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:54:57.427] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:54:59.750] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:01.746] [info] Newton iteration 2: r (abs) = 3.2205098006675083e-09 (tol = 1e-10), r (rel) = 4.1794471290189625e-09 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:01.993] [info] PETSc Krylov solver starting to solve system.
# Step 3: num iterations: 3
# [2025-03-12 11:55:04.075] [info] Newton iteration 3: r (abs) = 6.125056751130895e-15 (tol = 1e-10), r (rel) = 7.948850473389744e-15 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:04.075] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:04.076] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:04.479] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:05.921] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:07.317] [info] Newton iteration 2: r (abs) = 1.5059685384621728e-09 (tol = 1e-10), r (rel) = 2.2228196439033607e-09 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:07.565] [info] PETSc Krylov solver starting to solve system.
# Step 4: num iterations: 3
# [2025-03-12 11:55:08.638] [info] Newton iteration 3: r (abs) = 6.1415143191659e-15 (tol = 1e-10), r (rel) = 9.064916247118955e-15 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:08.638] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:08.638] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:09.042] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:10.336] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:11.367] [info] Newton iteration 2: r (abs) = 9.00091965813922e-10 (tol = 1e-10), r (rel) = 1.4531293834249902e-09 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:11.609] [info] PETSc Krylov solver starting to solve system.
# Step 5: num iterations: 3
# [2025-03-12 11:55:13.727] [info] Newton iteration 3: r (abs) = 6.117626665279966e-15 (tol = 1e-10), r (rel) = 9.876438632694498e-15 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:13.728] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:13.728] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:14.159] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:15.707] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:16.926] [info] Newton iteration 2: r (abs) = 6.052165896013292e-10 (tol = 1e-10), r (rel) = 1.0473283255897887e-09 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:17.161] [info] PETSc Krylov solver starting to solve system.
# Step 6: num iterations: 3
# [2025-03-12 11:55:18.974] [info] Newton iteration 3: r (abs) = 6.133794302405573e-15 (tol = 1e-10), r (rel) = 1.0614541350365697e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:18.974] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:18.974] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:19.440] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:21.603] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:23.504] [info] Newton iteration 2: r (abs) = 4.395964878635466e-10 (tol = 1e-10), r (rel) = 8.051645660504513e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:23.744] [info] PETSc Krylov solver starting to solve system.
# Step 7: num iterations: 3
# [2025-03-12 11:55:25.651] [info] Newton iteration 3: r (abs) = 6.127312185450277e-15 (tol = 1e-10), r (rel) = 1.122277996539659e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:25.651] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:25.651] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:26.067] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:28.536] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:30.031] [info] Newton iteration 2: r (abs) = 3.353926393241086e-10 (tol = 1e-10), r (rel) = 6.446017054928451e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:30.275] [info] PETSc Krylov solver starting to solve system.
# Step 8: num iterations: 3
# [2025-03-12 11:55:32.016] [info] Newton iteration 3: r (abs) = 6.133155291248315e-15 (tol = 1e-10), r (rel) = 1.1787504844346629e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:32.016] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:32.016] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:32.435] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:34.020] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:35.118] [info] Newton iteration 2: r (abs) = 2.657611103543155e-10 (tol = 1e-10), r (rel) = 5.325857900638739e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:35.353] [info] PETSc Krylov solver starting to solve system.
# Step 9: num iterations: 3
# [2025-03-12 11:55:36.627] [info] Newton iteration 3: r (abs) = 6.115107568175714e-15 (tol = 1e-10), r (rel) = 1.225468764478148e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:36.627] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:36.628] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:37.068] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:39.719] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:41.298] [info] Newton iteration 2: r (abs) = 2.1634067295313486e-10 (tol = 1e-10), r (rel) = 4.498867082347659e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:41.542] [info] PETSc Krylov solver starting to solve system.
# Step 10: num iterations: 3[2025-03-12 11:55:43.123] [info] Newton iteration 3: r (abs) = 6.11962104911433e-15 (tol = 1e-10), r (rel) = 1.2725929580641698e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:43.123] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
#
# [2025-03-12 11:55:43.124] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:43.619] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:45.582] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:47.198] [info] Newton iteration 2: r (abs) = 1.8015196538418903e-10 (tol = 1e-10), r (rel) = 3.872734338677328e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:47.453] [info] PETSc Krylov solver starting to solve system.
# Step 11: num iterations: 3
# [2025-03-12 11:55:49.139] [info] Newton iteration 3: r (abs) = 6.1147248990291875e-15 (tol = 1e-10), r (rel) = 1.3144849703712374e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:49.139] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:49.140] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:49.599] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:51.313] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:52.978] [info] Newton iteration 2: r (abs) = 1.5259763460081122e-10 (tol = 1e-10), r (rel) = 3.3806692541623796e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:53.213] [info] PETSc Krylov solver starting to solve system.
# Step 12: num iterations: 3
# [2025-03-12 11:55:54.368] [info] Newton iteration 3: r (abs) = 6.114767419440491e-15 (tol = 1e-10), r (rel) = 1.354674092120325e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:54.368] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:55:54.368] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:55:54.833] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:56.493] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:55:58.385] [info] Newton iteration 2: r (abs) = 1.3122900936356665e-10 (tol = 1e-10), r (rel) = 2.9885167322963297e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:55:58.620] [info] PETSc Krylov solver starting to solve system.
# Step 13: num iterations: 3[2025-03-12 11:56:00.219] [info] Newton iteration 3: r (abs) = 6.133571031204351e-15 (tol = 1e-10), r (rel) = 1.3968161265851425e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:00.219] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
#
# [2025-03-12 11:56:00.219] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:56:00.644] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:02.159] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:03.885] [info] Newton iteration 2: r (abs) = 1.141828342627861e-10 (tol = 1e-10), r (rel) = 2.6672858429039796e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:04.134] [info] PETSc Krylov solver starting to solve system.
# Step 14: num iterations: 3
# [2025-03-12 11:56:05.617] [info] Newton iteration 3: r (abs) = 6.123372014366126e-15 (tol = 1e-10), r (rel) = 1.4304062068702995e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:05.617] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:56:05.617] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:56:06.107] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:07.859] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:09.284] [info] Newton iteration 2: r (abs) = 1.004303969008538e-10 (tol = 1e-10), r (rel) = 2.4020695841689635e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:09.528] [info] PETSc Krylov solver starting to solve system.
# Step 15: num iterations: 3
# [2025-03-12 11:56:10.973] [info] Newton iteration 3: r (abs) = 6.126862312766819e-15 (tol = 1e-10), r (rel) = 1.465407890642636e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:10.973] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 11:56:10.973] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:56:11.391] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:13.148] [info] PETSc Krylov solver starting to solve system.
# Step 16: num iterations: 2
# [2025-03-12 11:56:14.920] [info] Newton iteration 2: r (abs) = 8.908934807615747e-11 (tol = 1e-10), r (rel) = 2.178294835189153e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:14.920] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 11:56:14.921] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:56:15.389] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:16.895] [info] PETSc Krylov solver starting to solve system.
# Step 17: num iterations: 2
# [2025-03-12 11:56:18.184] [info] Newton iteration 2: r (abs) = 7.967139309811752e-11 (tol = 1e-10), r (rel) = 1.9886993718247632e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:18.184] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 11:56:18.185] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:56:18.661] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:20.633] [info] PETSc Krylov solver starting to solve system.
# Step 18: num iterations: 2
# [2025-03-12 11:56:22.542] [info] Newton iteration 2: r (abs) = 7.17102387135696e-11 (tol = 1e-10), r (rel) = 1.825167155750764e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:22.542] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 11:56:22.543] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:56:23.048] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:24.618] [info] PETSc Krylov solver starting to solve system.
# Step 19: num iterations: 2
# [2025-03-12 11:56:26.353] [info] Newton iteration 2: r (abs) = 6.495136631474122e-11 (tol = 1e-10), r (rel) = 1.683840746430599e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:26.353] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 11:56:26.353] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 11:56:26.819] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 11:56:28.608] [info] PETSc Krylov solver starting to solve system.
# Step 20: num iterations: 2
# [2025-03-12 11:56:30.240] [info] Newton iteration 2: r (abs) = 5.912810404703885e-11 (tol = 1e-10), r (rel) = 1.5598626286064606e-10 (tol = 1.4901161193847657e-10)
# [2025-03-12 11:56:30.240] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 11:56:30.241] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
