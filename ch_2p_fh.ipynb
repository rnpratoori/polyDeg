# %% [markdown]
# # Cahn-Hilliard Equation using Flory-Huggins
#
# This is the implementation for Cahn-Hilliard Equation for two phase separation in 2D using FEniCSx.
# The boundary-value problem is described by:
# $$\frac{\partial c}{\partial t} - \nabla \cdot M \left( \nabla \left( \frac{\partial f}{\partial c} - \frac{\epsilon^2}{2} \Delta c \right) \right) = 0 \quad \in \Omega$$
#
# We use split formulation to rephrase the fourth-order equation into two coupled second-order equations:
# $$
# \begin{aligned}
# \frac{\partial c}{\partial t} - \nabla \cdot M \nabla \mu &= 0 \quad \in \Omega\\
# \mu - \frac{\partial f}{\partial c} + \frac{\epsilon^2}{2} \Delta c &= 0 \quad \in \Omega
# \end{aligned}
# $$
#
# ## Variational formulation
#
# ### Weak formulation
#
# The variational form of the equations are:
# $$
# \begin{aligned}
# \int_\Omega \frac{\partial c}{\partial t} q dx + \int_\Omega M \nabla \mu \cdot \nabla q dx = 0 \\
# \int_\Omega \mu v dx - \int_\Omega \frac{\partial f}{\partial c} v dx - \int_\Omega \frac{\epsilon^2}{2} \nabla c \cdot \nabla v dx = 0
# \end{aligned}
# $$
#
# ### Crank-Nicholson time stepper
#
# The sampling of the first PDE at time $t_{n+1}$ is given by:
# $$
# \begin{aligned}
# \int_\Omega \frac{c_{n+1} - c_n}{dt} q dx + \frac{1}{2} \int_\Omega M \nabla \left( \mu_{n+1} + \mu_n \right) \cdot \nabla q dx = 0 \\
# \int_\Omega \mu_{n+1} v dx - \int_\Omega \frac{d f_{n+1}}{dc} v dx - \int_\Omega \frac{\epsilon^2}{2} \nabla c_{n+1} \cdot \nabla v dx = 0
# \end{aligned}
# $$
#
# ## Problem definition
#
# - Domain: $\Omega = [0,1] \times [0,1]$
# - Local energy: $f = \frac{R T}{V} \left[ \frac{\phi_1}{N_1} \ln \phi_1 + \frac{\phi_2}{N_2} \ln \phi_2 + \chi_{1,2} \phi_1 \phi_2 \right]$
# - Gradient energy coefficent: $\lambda = 1 \times 10^{-2}$
# - Mobility coefficient: $M = 1$
# - Flory-Huggins parameter: $\chi_{1,2} = 3$
# - Length of polymer chains: $N_1 = N_2 = 1$

# %%
# Import Libraries
from mpi4py import MPI
from dolfinx import mesh, fem, io, log, default_real_type
import numpy as np
import ufl
from basix.ufl import element, mixed_element
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from petsc4py import PETSc
from pathlib import Path

# %%
# Define simulation parameters
J2eV = 1 # convert to eV
R = 1.0
T = 1.0
V = 1.0
epsilon_ = 0.02
lambda_ = epsilon_
M = 1.0
chi = 2.0
N1 = 5.0
N2 = 5.0
dt = 5.0e-05
T = 1.0e-03 # End time
num_steps = T / dt # Number of time steps
# Print properties
print(f"M={M}, V={V}, R={R}, lambda={lambda_}")

# Create mesh
domain = mesh.create_rectangle(MPI.COMM_WORLD, [np.array([0, 0]), np.array([2, 1])], [512, 256], mesh.CellType.quadrilateral)

# Create FunctionSpace
P1 = element("Lagrange", domain.basix_cell(), 1, dtype=default_real_type)
ME = fem.functionspace(domain, mixed_element([P1, P1]))

# Apply Dirichlet BCs
# Identify the facets on the left and right boundaries
facets = mesh.locate_entities_boundary(domain, domain.topology.dim - 1, lambda x: np.full(x.shape[1], True, dtype=bool))

# Define variational problem
# Define trial and test functions
u = fem.Function(ME)
# Previous solution
u0 = fem.Function(ME)
q, v = ufl.TestFunctions(ME)
# Split mixed functions
c, mu = ufl.split(u)
c0, mu0 = ufl.split(u0)

# Initial condition
u.x.array[:] = 0.0
rng = np.random.default_rng(2)
u.sub(0).interpolate(lambda x: 0.5 + 0.02 * (0.5 - rng.random(x.shape[1])))
u.x.scatter_forward()

# Compute df/dc
c = ufl.variable(c)
f = (R * T / V) * (c * ufl.ln(c) / N1 + (1 - c) * ufl.ln(1 - c) / N2 + chi * c * (1 - c))
dfdc = ufl.diff(f, c)

# Define residuals
F0 = ufl.inner(c, q) * ufl.dx - ufl.inner(c0, q) * ufl.dx + (dt/2) * ufl.inner(ufl.grad(mu + mu0), ufl.grad(q)) * ufl.dx
F1 = ufl.inner(mu, v) * ufl.dx - ufl.inner(dfdc, v) * ufl.dx - lambda_ * ufl.inner(ufl.grad(c), ufl.grad(v)) * ufl.dx
F = F0 + F1

# Create NonlinearProblem
problem = NonlinearProblem(F, u)

# Create Newton Solver
log.set_log_level(log.LogLevel.INFO)
solver = NewtonSolver(domain.comm, problem)
solver.convergence_criterion = "incremental"
solver.rtol = np.sqrt(np.finfo(default_real_type).eps) * 1e-2
ksp = solver.krylov_solver
opts = PETSc.Options()  # type: ignore
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "preonly"
opts[f"{option_prefix}pc_type"] = "lu"
sys = PETSc.Sys()  # type: ignore
# For factorisation prefer MUMPS, then superlu_dist, then default
use_superlu = PETSc.IntType == np.int64  # or PETSc.ScalarType == np.complex64
if sys.hasExternalPackage("mumps") and not use_superlu:
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
elif sys.hasExternalPackage("superlu_dist"):
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "superlu_dist"
ksp.setFromOptions()

# Post-process
# Save solution to file
t = 0.0
results_folder = Path("results")
results_folder.mkdir(exist_ok=True, parents=True)
filename = results_folder / "out_ch2p"
with io.XDMFFile(domain.comm, filename.with_suffix(".xdmf"), "w", io.XDMFFile.Encoding.ASCII) as xdmf:
    xdmf.write_mesh(domain)
# Get the sub-space for c
V0, dofs = ME.sub(0).collapse()

# Time-stepping
c = u.sub(0)
u0.x.array[:] = u.x.array
while t < T:
    t += dt
    r = solver.solve(u)
    print(f"Step {int(t / dt)}: num iterations: {r[0]}")
    u0.x.array[:] = u.x.array
    xdmf.write_function(c, t)
xdmf.close()
# Out:
# M=1.0, V=1.0, R=1.0, lambda=0.02
# [2025-03-12 12:23:24.596] [info] Extract basic topology: 524288->524288
# [2025-03-12 12:23:24.596] [info] Build local dual graph
# [2025-03-12 12:23:24.596] [info] Build local part of mesh dual graph (mixed)
# [2025-03-12 12:23:24.617] [info] GPS pseudo-diameter:(767) 131071-0
# [2025-03-12 12:23:24.622] [info] Create topology (single cell type)
# [2025-03-12 12:23:24.622] [info] Create topology (generalised)
# [2025-03-12 12:23:24.625] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 1
# [2025-03-12 12:23:24.625] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 1
# [2025-03-12 12:23:24.652] [info] Compute ghost indices
# [2025-03-12 12:23:24.652] [info] Computing communication graph edges (using PCX algorithm). Number of input edges: 0
# [2025-03-12 12:23:24.652] [info] Finished graph edge discovery using PCX algorithm. Number of discovered edges 0
# [2025-03-12 12:23:24.683] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# [2025-03-12 12:23:24.683] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# [2025-03-12 12:23:24.687] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# [2025-03-12 12:23:24.687] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# [2025-03-12 12:23:24.687] [info] Number of neighbourhood source ranks in distribute_to_postoffice: 0
# [2025-03-12 12:23:24.687] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# [2025-03-12 12:23:24.687] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# [2025-03-12 12:23:24.687] [info] Neighbourhood destination ranks from post office in distribute_data (rank, num dests, num dests/mpi_size): 0, 0, 0
# [2025-03-12 12:23:24.688] [info] Checking required entities per dimension
# [2025-03-12 12:23:24.688] [info] Cell type: 0 dofmap: 131072x4
# [2025-03-12 12:23:24.693] [info] Global index computation
# [2025-03-12 12:23:24.694] [info] Got 1 index_maps
# [2025-03-12 12:23:24.694] [info] Get global indices
# [2025-03-12 12:23:24.706] [info] Checking required entities per dimension
# [2025-03-12 12:23:24.707] [info] Cell type: 0 dofmap: 131072x8
# [2025-03-12 12:23:24.711] [info] Global index computation
# [2025-03-12 12:23:24.711] [info] Got 1 index_maps
# [2025-03-12 12:23:24.712] [info] Get global indices
# [2025-03-12 12:23:24.713] [info] Computing mesh entities of dimension 1
# [2025-03-12 12:23:24.737] [info] Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# [2025-03-12 12:23:24.737] [info] Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# [2025-03-12 12:23:24.741] [info] Requesting connectivity (1, 0) - (2, 0)
# [2025-03-12 12:23:24.741] [info] Computing mesh connectivity 1-2 from transpose.
# [2025-03-12 12:23:24.742] [info] Requesting connectivity (1, 0) - (0, 0)
# [2025-03-12 12:23:24.742] [info] Requesting connectivity (1, 0) - (1, 0)
# [2025-03-12 12:23:24.742] [info] Requesting connectivity (0, 0) - (2, 0)
# [2025-03-12 12:23:24.742] [info] Computing mesh connectivity 0-2 from transpose.
# [2025-03-12 12:23:24.742] [info] Requesting connectivity (2, 0) - (0, 0)
# [2025-03-12 12:23:25.185] [info] Column ghost size increased from 0 to 0
# [2025-03-12 12:23:25.189] [info] Adding mesh to node "/Xdmf/Domain"
# [2025-03-12 12:23:25.189] [info] Adding topology data to node /Xdmf/Domain/Grid
# [2025-03-12 12:23:25.205] [info] Adding geometry data to node "/Xdmf/Domain/Grid"
# [2025-03-12 12:23:25.471] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:23:28.485] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:23:30.650] [info] Newton iteration 2: r (abs) = 3.5234928830833486e-09 (tol = 1e-10), r (rel) = 1.1621518137670386e-09 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:23:30.798] [info] PETSc Krylov solver starting to solve system.
# Step 1: num iterations: 3
# [2025-03-12 12:23:32.906] [info] Newton iteration 3: r (abs) = 4.0306418292277196e-14 (tol = 1e-10), r (rel) = 1.3294244852804156e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:23:32.906] [info] Newton solver finished in 3 iterations and 3 linear solver iterations.
# [2025-03-12 12:23:32.907] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:23:33.141] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:23:35.402] [info] PETSc Krylov solver starting to solve system.
# Step 2: num iterations: 2
# [2025-03-12 12:23:37.535] [info] Newton iteration 2: r (abs) = 6.182913294153552e-12 (tol = 1e-10), r (rel) = 1.793420676979136e-12 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:23:37.535] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:23:37.535] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:23:37.772] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:23:40.119] [info] PETSc Krylov solver starting to solve system.
# Step 3: num iterations: 2
# [2025-03-12 12:23:42.321] [info] Newton iteration 2: r (abs) = 1.3397414415565546e-12 (tol = 1e-10), r (rel) = 4.842852391623971e-13 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:23:42.321] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:23:42.321] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:23:42.565] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:23:44.905] [info] PETSc Krylov solver starting to solve system.
# Step 4: num iterations: 2
# [2025-03-12 12:23:47.134] [info] Newton iteration 2: r (abs) = 5.00468402676921e-13 (tol = 1e-10), r (rel) = 2.026186107220518e-13 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:23:47.134] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:23:47.135] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:23:47.382] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:23:49.728] [info] PETSc Krylov solver starting to solve system.
# Step 5: num iterations: 2
# [2025-03-12 12:23:51.967] [info] Newton iteration 2: r (abs) = 2.9573609969555834e-13 (tol = 1e-10), r (rel) = 1.2952967286011924e-13 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:23:51.967] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:23:51.967] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:23:52.218] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:23:54.632] [info] PETSc Krylov solver starting to solve system.
# Step 6: num iterations: 2
# [2025-03-12 12:23:56.886] [info] Newton iteration 2: r (abs) = 1.822512060455077e-13 (tol = 1e-10), r (rel) = 8.481759364818215e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:23:56.886] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:23:56.886] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:23:57.143] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:23:59.585] [info] PETSc Krylov solver starting to solve system.
# Step 7: num iterations: 2
# [2025-03-12 12:24:01.827] [info] Newton iteration 2: r (abs) = 1.3035214870949144e-13 (tol = 1e-10), r (rel) = 6.373816677297464e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:01.827] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:01.827] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:02.082] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:04.547] [info] PETSc Krylov solver starting to solve system.
# Step 8: num iterations: 2
# [2025-03-12 12:24:06.763] [info] Newton iteration 2: r (abs) = 9.687920798630737e-14 (tol = 1e-10), r (rel) = 4.9391519914211354e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:06.763] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:06.764] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:07.020] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:09.335] [info] PETSc Krylov solver starting to solve system.
# Step 9: num iterations: 2
# [2025-03-12 12:24:11.617] [info] Newton iteration 2: r (abs) = 7.770031976048272e-14 (tol = 1e-10), r (rel) = 4.107240762407663e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:11.617] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:11.617] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:11.873] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:14.254] [info] PETSc Krylov solver starting to solve system.
# Step 10: num iterations: 2
# [2025-03-12 12:24:16.510] [info] Newton iteration 2: r (abs) = 6.637800876630361e-14 (tol = 1e-10), r (rel) = 3.622513430327019e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:16.510] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:16.510] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:16.769] [info] PETSc Krylov solver starting to solve system.
# Step 11: num iterations: 2
# [2025-03-12 12:24:19.158] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:21.436] [info] Newton iteration 2: r (abs) = 6.172362579751607e-14 (tol = 1e-10), r (rel) = 3.46604275231135e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:21.436] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:21.436] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:21.696] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:24.131] [info] PETSc Krylov solver starting to solve system.
# Step 12: num iterations: 2
# [2025-03-12 12:24:26.407] [info] Newton iteration 2: r (abs) = 5.460692775133745e-14 (tol = 1e-10), r (rel) = 3.1466471092225825e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:26.407] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:26.408] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:26.677] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:29.076] [info] PETSc Krylov solver starting to solve system.
# Step 13: num iterations: 2
# [2025-03-12 12:24:31.435] [info] Newton iteration 2: r (abs) = 5.2946621486929386e-14 (tol = 1e-10), r (rel) = 3.1237755041675536e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:31.435] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:31.435] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:31.703] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:34.157] [info] PETSc Krylov solver starting to solve system.
# Step 14: num iterations: 2
# [2025-03-12 12:24:36.601] [info] Newton iteration 2: r (abs) = 4.924784052772151e-14 (tol = 1e-10), r (rel) = 2.969278797793331e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:36.601] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:36.602] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:36.876] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:39.317] [info] PETSc Krylov solver starting to solve system.
# Step 15: num iterations: 2
# [2025-03-12 12:24:41.597] [info] Newton iteration 2: r (abs) = 4.6521552214923745e-14 (tol = 1e-10), r (rel) = 2.8618151022844e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:41.597] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:41.598] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:41.859] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:44.192] [info] PETSc Krylov solver starting to solve system.
# Step 16: num iterations: 2
# [2025-03-12 12:24:46.413] [info] Newton iteration 2: r (abs) = 4.4772904810211075e-14 (tol = 1e-10), r (rel) = 2.8062353120650187e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:46.413] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:46.413] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:46.683] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:49.102] [info] PETSc Krylov solver starting to solve system.
# Step 17: num iterations: 2
# [2025-03-12 12:24:51.453] [info] Newton iteration 2: r (abs) = 4.529087670844676e-14 (tol = 1e-10), r (rel) = 2.8887958023204456e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:51.453] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:51.454] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:51.728] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:54.126] [info] PETSc Krylov solver starting to solve system.
# Step 18: num iterations: 2
# [2025-03-12 12:24:56.385] [info] Newton iteration 2: r (abs) = 4.489923413141876e-14 (tol = 1e-10), r (rel) = 2.9112622445163205e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:24:56.385] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:24:56.386] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:24:56.664] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:24:59.024] [info] PETSc Krylov solver starting to solve system.
# Step 19: num iterations: 2[2025-03-12 12:25:01.274] [info] Newton iteration 2: r (abs) = 4.5099509302855634e-14 (tol = 1e-10), r (rel) = 2.969909207987951e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:25:01.274] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
#
# [2025-03-12 12:25:01.275] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
# [2025-03-12 12:25:01.553] [info] PETSc Krylov solver starting to solve system.
# [2025-03-12 12:25:03.958] [info] PETSc Krylov solver starting to solve system.
# Step 20: num iterations: 2
# [2025-03-12 12:25:06.227] [info] Newton iteration 2: r (abs) = 4.291350196317784e-14 (tol = 1e-10), r (rel) = 2.8676770919948634e-14 (tol = 1.4901161193847657e-10)
# [2025-03-12 12:25:06.227] [info] Newton solver finished in 2 iterations and 2 linear solver iterations.
# [2025-03-12 12:25:06.227] [info] Adding function to node "/Xdmf/Domain/Grid/Grid"
